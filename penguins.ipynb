# %% [markdown]
# # Palmer Penguins
# # This note book contains analysis of palmer penguis data set

# %%
import pandas as pd
import matplotlib.pyplot as plt # imports the Matplotlib library

# %% [markdown]
# Python for Dummies - All in One - John Shovic,  Alan Simpson ~ Doing Data Science with Python Chaper 2  Page439 pandas / MatPlotLib
# https://www.geeksforgeeks.org/data-visualization-in-jupyter-notebook/
# https://realpython.com/python-matplotlib-guide/
# https://realpython.com/python-matplotlib-guide/#plotting-in-pandas

# %%
df = pd.read_csv ("https://raw.githubusercontent.com/DBrennan88/Principles-of-Data-Analytics/main/penguins_raw_data.csv")
# URL of the Palmer Penguins dataset
# Load the dataset into a DataFrame

# %%
df
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %%
df.iloc [0]
# Out:
# studyName                                          PAL0708
# Sample Number                                            1
# Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Individual ID                                         N1A1
# Clutch Completion                                      Yes
# Date Egg                                        2007-11-11
# Culmen Length (mm)                                    39.1
# Culmen Depth (mm)                                     18.7
# Flipper Length (mm)                                  181.0
# Body Mass (g)                                       3750.0
# Sex                                                   MALE
# Delta 15 N (o/oo)                                      NaN
# Delta 13 C (o/oo)                                      NaN
# ...

# %% [markdown]
# Taken from course material

# %%
# Compare sex of penguins in data set
df ["Sex"].value_counts()
# Out:
# Sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
df.head # shows me first few rows
# Out:
# <bound method NDFrame.head of     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
# ...

# %%
df.info # summary of a DataFrame, including the number of non-null values, data types, and memory usage. quick overview of  structure of dataset.
# Out:
# <bound method DataFrame.info of     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
# ...

# %%
# Creating my bar chart of penguin species

import matplotlib.pyplot as plt # call external lib to access function. pypplot module allows to customize plotting to chars graphs etc 
df["Species"].value_counts().plot(kind="bar", color="blue") # countspecies in dataset "df" plot in bar chart.color yellow bars. #Errors on previous run due to lower case "s" in Species :(
plt.title("Penguin Species") # Chart titles
plt.xlabel("Species") # Axis labels
plt.ylabel("Count") # Axis labels
plt.xticks(rotation=40) # to display my x axis labels at an angle
plt.show() # display output

# %% [markdown]
# https://stackoverflow.com/questions/39278279/plot-a-bar-graph-for-pandas-with-x-axis-using-a-given-column
#
# https://app.datacamp.com/learn/courses/introduction-to-data-visualization-with-matplotlib

# %%
# Creating my histogram of Species fliper lengh Flipper Length (mm)
import matplotlib.pyplot as plt # missing from earlier iterations causing this kernal to fail
plt.hist(df["Flipper Length (mm)"], bins=50, color="red") # divide flipper length across the data set. data slices into "bins" or intervals. 
plt.title("Flipper Length")
plt.xlabel("Flipper Length (mm)")
plt.ylabel("Frequency") # usiing frequency on y axis to display number pengins with flipper length within the range of each "bin"
plt.show()

# %% [markdown]
# https://www.w3schools.com/python/matplotlib_histograms.asp
# https://www.statology.org/python-histogram-from-list/
# https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/

# %%
"""Creating my histogram of average fliper lengh per species
import matplotlib.pyplot as plt
avg_flipper_length = df.groupby("Species")["Flipper Length (mm)"].mean() # Syntax and later case inconsistencies causing errors
plt.hist(df["Flipper Length (mm)"], bins=50, color="red") # divide flipper length across the data set. data slices into "bins" or intervals. 
plt.title("Flipper Length")
plt.xlabel("Species")
plt.ylabel("Flipper Length (mm)") # usiing frequency on y axis to display number pengins with flipper length within the range of each "bin"
plt.show()""" #Not displaying information as i hoped.  Histo maybe not the correct type for this.
# Out:
# 'Creating my histogram of average fliper lengh per species\nimport matplotlib.pyplot as plt\navg_flipper_length = df.groupby("Species")["Flipper Length (mm)"].mean() # Syntax and later case inconsistencies causing errors\nplt.hist(df["Flipper Length (mm)"], bins=50, color="red") # divide flipper length across the data set. data slices into "bins" or intervals. \nplt.title("Flipper Length")\nplt.xlabel("Species")\nplt.ylabel("Flipper Length (mm)") # usiing frequency on y axis to display number pengins with flipper length within the range of each "bin"\nplt.show()'

# %% [markdown]
# https://stackoverflow.com/questions/49970309/pandas-groupby-with-mean
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.DataFrameGroupBy.mean.html
# https://stackoverflow.com/questions/43005462/pandas-bar-plot-with-binned-range
